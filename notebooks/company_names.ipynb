# %%
import pandas as pd
from random import random, seed
from stop_words import get_stop_words

# %%
# Some Probability settings to generate various case variations in names
seed(15)
suffix_threshold = 0.4
lc_threshold = 0.25
formcase_threshold = 0.5
capitalize_threshold = 0.5

# %%
stopwords = get_stop_words('en')

# %%
filepath = 'corpwatch_api_tables_csv/companies.csv'
df = pd.read_csv(filepath, delimiter='\t')
unique_companies = df['company_name'].unique().tolist()

# %%
removable_suffixes = [i.lower() for i in ['& CO', 'corp', 'CO', 'LTD', 'INC', 'Co', 'LLC']]

print(removable_suffixes)

# %%
# Creates case variations for COMPANY NAMES
def case_formalize(company):
    if random() > capitalize_threshold:
        return company.capitalize()
    else:
        tokens = company.split()
        ntokens = []
        for i, token in enumerate(tokens):
            if token in stopwords and i>0:
                ntokens.append(token.lower())
            else:
                ntokens.append(token.capitalize())
        return ' '.join(ntokens)

# %%
processed_companies = []
for company in unique_companies:
    
    chance = random()
    if chance < lc_threshold:
        ncompany = company.lower()
    elif chance < lc_threshold + formcase_threshold:
        ncompany = case_formalize(company)
    else:
        ncompany = company
    
    if random()<suffix_threshold:
        for suffix in removable_suffixes:
            if ncompany.lower().endswith(suffix):
                ncompany = ncompany[:-1*(len(suffix)+1)]
                break
    
    processed_companies.append(ncompany)

# %%
processed_companies
# Out:
# ['CORPORATE INCOME FUND SEVENTY NINTH SHORT TERM SERIES',
#  'K Tron International Inc',
#  'aar corp',
#  'Abbott laboratories',
#  'abel noser',
#  'Abercrombie & Fitch',
#  'aberdeen idaho mining co',
#  'ABRAHAM & CO INC',
#  'merchanthouse securities inc',
#  'Abrams Industries Inc',
#  'Worlds Com Inc',
#  'Ametech inc',
#  'Accel International Corp',
#  'ACE HARDWARE CORP',
#  'ACETO',
#  'acmat',
#  'ACME ELECTRIC CORP',
#  'Acme United Corp',
#  'LIBERTY ACORN TRUST',
#  'affiliated computer services',
#  'Adams resources & energy inc',
#  'Relm wireless',
#  'ADAMS EXPRESS',
#  'prospera financial services',
#  'ADMINISTRATIVE DATA MANAGEMENT',
#  'ADMINISTRATIVE SYSTEMS',
#  'Advanced Computer Techniques Corp',
#  'ADVANCED DIGITAL SYSTEMS INC',
#  'advanced micro devices inc',
#  'Alliance gaming corp',
#  'Aei Securities',
#  'AERO SYSTEMS ENGINEERING INC',
#  'aeroflex inc',
#  'Aerosonic',
#  'ing vp bond portfolio',
#  'Ing Vp Money Market Portfolio',
#  'Ing variable funds',
#  'afa protective systems',
#  'Lord abbett affiliated fund',
#  'Lumiere securities inc',
#  'Afrikander Lease Ltd',
#  'AFTER SIX INC',
#  'FRANKLIN HIGH INCOME TRUST',
#  'Royal Lane Securities',
#  'Agf Securities',
#  'AGNICO EAGLE MINES',
#  'AGRI DYNAMICS INC',
#  'Texas American Resources Inc',
#  'Agway',
#  'foothill securities inc',
#  'Aic International Inc',
#  'Air Products & Chemicals Inc',
#  'airborne',
#  'Airtex products inc',
#  'Akorn',
#  'AKZO NOBEL NV',
#  'AMSOUTH BANCORPORATION',
#  'Alabama gas corp',
#  'Alabama power co',
#  'Alabama Telephone Co Inc',
#  'Ceco Environmental Corp',
#  'Alaska Airlines Inc',
#  'ALASKA POWER & TELEPHONE',
#  'ALBANY INTERNATIONAL CORP',
#  'Alberto Culver',
#  'albertsons',
#  'IKON OFFICE SOLUTIONS',
#  'AEIRE CORP',
#  'ALEXANDER & BALDWIN',
#  'Alexander Investment Services Co',
#  'ALEXANDERS INC',
#  'Alger fred management',
#  'alger fund',
#  'algonquin gas transmission llc',
#  'Algorex',
#  'Alico inc',
#  'Cheniere Energy Inc',
#  'All Funds Inc',
#  'ALLCITY INSURANCE',
#  'ALLEGHENY ENERGY',
#  'Allen & co',
#  'Allen telecom inc',
#  'Allen Organ Co',
#  'Alliancebernstein bond fund',
#  'ACMC INC',
#  'Allied investment',
#  'ALLIED CAPITAL CORP',
#  'Allied products corp',
#  'Allied Research',
#  'ITIS HOLDINGS INC',
#  'Allied tube & conduit corp',
#  'Allied van lines inc',
#  'allis chalmers corp',
#  'ALLISON M E & CO',
#  'ALLISON WILLIAMS Co',
#  'Enterprise group of funds inc',
#  'skyworks solutions inc',
#  'alpine group',
#  'ASIA SUPERNET CORP',
#  'Industrial services of america',
#  'Altobelli richard joseph',
#  'Alcoa Inc',
#  'Alcan inc',
#  'ALZA',
#  'Sento',
#  'Apparel America',
#  'amana society inc',
#  'bestway inc',
#  'amcap fund inc',
#  'Amerada Hess',
#  'Ame',
#  'u haul international inc',
#  'AMERICAN AIRLINES',
#  'American automotive corp',
#  'American balanced fund inc',
#  'AMERICAN BANCSERVICES INC TA',
#  'American biltrite',
#  'AMERICA CAPITAL',
#  'American Consumers Inc',
#  'American crystal sugar',
#  'Wpg large cap growth fund',
#  'American Electric Power Co Inc',
#  'AMERICAN EXPRESS CO',
#  'American Express Credit',
#  'AFLAC INC',
#  'american family life insurance co',
#  'american fidelity',
#  'American fidelity securities',
#  'american fidelity separate account a',
#  'AMERICAN FINANCIAL',
#  'american funds & trusts',
#  'AMERICAN FUNDS SERVICE CO',
#  'VAN KAMPEN BOND FUND',
#  'Advantage Capital Corp',
#  'VAN KAMPEN EXCHANGE FUND',
#  'American general life insurance co',
#  'Van Kampen Reserve Fund',
#  'VAN KAMPEN EMERGING GROWTH FUND',
#  'EMTEC INC',
#  'American Greetings',
#  'AMERICAN GROWTH FUND',
#  'AMERICAN GROWTH FUND SPONSORS INC',
#  'American home assurance co',
#  'WYETH',
#  'American Hospital Management Corp',
#  'american income fund inc',
#  'AIG EQUITY SALES',
#  'American international group',
#  'AMERICAN ISRAELI PAPER MILLS LTD',
#  'Federated american leaders fund inc',
#  'keystone liquid trust',
#  'AMERICAN MORTGAGE & INVESTMENT',
#  'American Mutual Fund',
#  'Unumprovident',
#  'American nuclear',
#  'American pad & paper co',
#  'AMERICAN INTERNATIONAL VENTURES INC',
#  'American Registrar & Transfer',
#  'american science & engineering inc',
#  'American securities bd co lp',
#  'American ship building co',
#  'American Standard',
#  'American States Insurance Co',
#  'AMERICAN STOCK TRANSFER & TRUST CO',
#  'AT&T',
#  'american television & communications',
#  'AUL AMERICAN LIFE POOLED EQUITY FUND B',
#  'american uranium',
#  'AMERICAN VANGUARD',
#  'ameron',
#  'ames department stores inc',
#  'Ametek Inc',
#  'ampco pittsburgh corp',
#  'Amr',
#  'AMREP CORP',
#  'Activa Mutual Fund Trust',
#  'Anacomp Inc',
#  'ANALOG DEVICES INC',
#  'Analogic corp',
#  'analysts international corp',
#  'Anaren',
#  'FIRST INVESTORS SGL P&PPP FOR THE ACCU OF SH OF AMCAP FD INC',
#  'aig sunamerica life assurance',
#  'andersen group',
#  'Anderson & Strudwick Inc',
#  'Andrea Electronics Corp',
#  'j d andrews',
#  'Angelica corp',
#  'Angeloff',
#  'K2',
#  'ANTICLINE URANIUM',
#  'Apache corp',
#  'COMFORCE',
#  'apogee enterprises inc',
#  'Appalachian power',
#  'Stage stores inc',
#  'INNOVATIVE MICRO TECHNOLOGY INC',
#  'APPLIED MATERIALS',
#  'ACTUANT CORP',
#  'ARAMARK SERVICES',
#  'Arabian american development co',
#  'Arbor',
#  'archer daniels midland',
#  'ARCHON INC',
#  'Argentina republic of',
#  'argonaut energy corp',
#  'Argus investors counsel inc',
#  'Washington mutual finance',
#  'arizona public service',
#  'ARKANSAS BEST HOLDINGS',
#  'ENTERGY ARKANSAS INC',
#  'southwestern energy',
#  'Arkwin Industries Inc',
#  'arlen corp',
#  'ARMSTRONG ASSOCIATES',
#  'Armstrong world industries',
#  'Natexis bleichroeder',
#  'arrow electronics inc',
#  'arts way manufacturing co inc',
#  'Asa',
#  'ASAHI GLASS CO LTD',
#  'Asarco Inc',
#  'ashland inc',
#  'Ashton Harris J',
#  'Asset Planning',
#  'Associated banc corp',
#  'Associated financial services',
#  'Asi technology corp',
#  'Associates first capital',
#  'astrex',
#  'Astronics Corp',
#  'astute investors corp',
#  'Athey products',
#  'Atkinson Guy F Co Of California',
#  'astro med inc',
#  'ATLANTA MOTOR SPEEDWAY INC',
#  'ATLANTIC AMERICAN CORP',
#  'Atlantic City Electric',
#  'Atlantis international corp',
#  'atlas consolidated mining & development corp',
#  'Atlas Minerals Inc',
#  'ATLAS MINING CO',
#  'ATLAS STOCK TRANSFER CORP',
#  'Atwood Oceanics',
#  'ATWOOD OCEANICS INC QUALIFIED STOCK OPTION PLANS',
#  'ONEAMERICA SECURITIES',
#  'Assuranceamerica corp',
#  'millennium plastics corp',
#  'commonwealth bank of australia',
#  'AUTO GRAPHICS INC',
#  'medicore inc',
#  'Automatic data processing inc',
#  'ambassador food services',
#  'autotronic systems',
#  'SEPARATE ACCOUNT VA B OF ALLMERICA FINAN LFE INS & ANN',
#  'Separate account va c of allmerica finan lfe ins & ann',
#  'El chem machinery inc',
#  'AVERY DENNISON',
#  'american locker group inc',
#  'Avnet Inc',
#  'AVON OVERSEAS CAPITAL',
#  'AVON PRODUCTS',
#  'AZTEC EQUITIES',
#  'azz inc',
#  'Beneficial',
#  'BABSON D L BOND TRUST',
#  'BABSON DAVID L & CO INC',
#  'babson david l growth fund inc',
#  'badger meter',
#  'Badger paper mills inc',
#  'JULIUS BAER SECURITIES',
#  'bagdad chase inc',
#  'WORLD WIDE LTD',
#  'bain & co inc',
#  'Baird Patrick & Co Inc',
#  'Robert w. baird & co',
#  'D. l. baker & co',
#  'bkf capital group',
#  'Baker michael corp',
#  'balanced security planning inc',
#  'bcg securities',
#  'Balchem Corp',
#  'Baldor electric co',
#  'Baldwin & lyons',
#  'baldwin montrose chemical co inc restric',
#  'Balfour investors',
#  'ball corp',
#  'BALTEK CORP',
#  'BALTIMORE GAS & ELECTRIC',
#  'bancroft convertible fund inc',
#  'BANCSHARES',
#  'Bandag',
#  'BANGOR HYDRO ELECTRIC',
#  'BANK OF AMERICA NA',
#  'bancorpsouth dealer bank department',
#  'Bank Of New York Co Inc',
#  'Bank Of Nova Scotia',
#  'Bank Of Oklahoma National Association',
#  'bank of tokyo',
#  'bre properties inc',
#  'bankers & investors',
#  'BANKERS FIDELITY LIFE INSURANCE CO',
#  'principal life insurance co',
#  'Principal life insurance co separate account b',
#  'reliastar life ins co of ny var annuity funds d e f g h & i',
#  'Bankers trust corp',
#  'Fairchild',
#  'Banta',
#  'Barclay investments inc',
#  'bard c r inc',
#  'Barnes group inc',
#  'BARNETT BANKS',
#  'Barnwell Industries Inc',
#  'BARR BROTHERS & CO INC',
#  'BARR LABORATORIES INC',
#  'BARRY R G CORP',
#  'basic earth science systems',
#  'Basic Investors Inc',
#  'basil investment corp',
#  'Bassett Furniture Industries Inc',
#  'Baumann investment',
#  'Bausch & Lomb Inc',
#  'BAXTER INTERNATIONAL',
#  'Bay state gas co',
#  'mutual beacon fund inc',
#  'BEACON INVESTMENT CO',
#  'BECHTEL FINANCING SERVICES LLC',
#  'Beck mack & oliver llc',
#  'Becker walt & associates',
#  'Becton dickinson',
#  'beekman securities corp',
#  'beeson thomas w',
#  'CARLYLE INDUSTRIES INC',
#  'Verizon Pennsylvania',
#  'Bellamah neuhauser & barrett inc',
#  'belo & co',
#  'Bemis co inc',
#  'BENGUET',
#  'Benthos inc',
#  'Berghoff & Co',
#  'Berkley w r corp',
#  'Bessemer securities corp',
#  'Bessemer Trust',
#  'best products co',
#  'BETHLEHEM',
#  'Bethlehem steel',
#  'Betzdearborn',
#  'beyer & co',
#  'Biddeford & saco water',
#  'SCIOTO INVESTMENT',
#  'FLANIGANS ENTERPRISES',
#  'Sames',
#  'Bio rad laboratories inc',
#  'Pyramid funds',
#  'SPHERIX INC',
#  'birkelbach',
#  'Bishop rosen & co inc',
#  'impala platinum holdings ltd',
#  'Black & decker corp',
#  'Broadband wireless international corp',
#  'black hills power inc',
#  'black james i',
#  'Blackburn & Co Inc',
#  'Howland capital management inc',
#  'WILLIAM BLAIR & Co',
#  'STRAND ATKINSON WILLIAMS & YORK',
#  'LEXINGTON PRECISION CORP',
#  'PRINCOR FINANCIAL SERVICES Corp',
#  'principal variable contracts fund inc',
#  'principal growth fund',
#  'principal capital value fund inc',
#  'H&R BLOCK INC',
#  'blount',
#  'BLUE CHIP STAMPS',
#  'Blue ridge real estate co',
#  'bodell overcash anderson & co inc',
#  'Boeing Co',
#  'BOENNING & SCATTERGOOD',
#  'BOGUE ELECTRIC MANUFACTURING',
#  'boise cascade',
#  'camelot corp',
#  'Bonanza gold',
#  'bond fund of america inc',
#  'secured diversified investment',
#  'BOOZ ALLEN & HAMILTON',
#  'avalon investment & securities group',
#  'borden chemical inc',
#  'Bormans Inc',
#  'borst investment planning services',
#  'Bossier bank & trust investment division',
#  'BOSTON Co ASSET MANAGEMENT LLC',
#  'boston edison',
#  'Federated stock & bond fund inc',
#  'Boston Gas Co',
#  'Boston institutional services inc',
#  'C A BOTZUM & CO',
#  'ENTRX',
#  'BOWL AMERICA INC',
#  'WHITE ELECTRONIC DESIGNS CORP',
#  'BOWNE & CO INC',
#  'Bradley woods & co',
#  'Bb&t funds',
#  'BRANDT ROBERT & CO',
#  'Bresler & reiner inc',
#  'bridges investment counsel inc',
#  'Bridges investment fund inc',
#  'Bridgford Foods',
#  'Briggs & Stratton Corp',
#  'BRIGHTON SECURITIES CORP',
#  'Brimberg & Co Lp',
#  'BRISTOL MYERS SQUIBB CO',
#  'Mktg Services Inc',
#  'British american insurance co ltd',
#  'Brittingham',
#  'Bdi investment corp',
#  'seligman common stock fund inc',
#  'Brodie exploration',
#  'BROTHER INDUSTRIES LTD',
#  'Smith brown & groover inc',
#  'Bns',
#  'brown associates',
#  'brown brothers harriman',
#  'Brown Forman',
#  'Brown shoe co inc',
#  'Brown lisle/cummings inc',
#  'FIRST WILSHIRE SECURITIES MANAGEMENT INC',
#  'BROWN STEPHEN L',
#  'Brown Tom Inc',
#  'Brt realty trust',
#  'Gordon Haskett & Co',
#  'brundage story & rose',
#  'brunswick',
#  'Dixon ticonderoga co',
#  'Btr Realty Inc',
#  'Buell Securities',
#  'DOLLAR RESERVES',
#  'Bull Inc',
#  'Bullion Monarch Mining',
#  'bulova corp',
#  'CHASE GENERAL CORP',
#  'Bureau Of National Affairs Inc',
#  'Burke Jb & Co',
#  'BURKE LAWTON BREWER & BURKE',
#  'Burke mills inc',
#  'Burlington Northern Railroad',
#  'MASTEC',
#  'emex',
#  'DIAMOND BAY SECURITIES CORP',
#  'J. BUSH & CO Inc',
#  'Butler international inc',
#  'Butler manufacturing',
#  'butler national corp',
#  'Butterfield jack v investment co',
#  'James C. Butterfield Inc',
#  'c & l securities',
#  'cabe w t & co inc',
#  'CABOT',
#  'CACI INTERNATIONAL INC',
#  'Lubys Inc',
#  'Cagles Inc',
#  'Cal Maine Foods',
#  'AGL SEPARATE ACCOUNT A',
#  'union bank of california n a',
#  'California engels mining co',
#  'Ab liquidating',
#  'Capital Trust',
#  'California water service co',
#  'Calprop corp',
#  'cambex',
#  'camco financial corp',
#  'cameron murphy & spangler',
#  'campbell kenneth l',
#  'campbell soup',
#  'O&Y PROPERTIES CORP',
#  'TRIZAK CORP',
#  'canada southern petroleum',
#  'Canadian Imperial Bank Of Commerce',
#  'Mfc Bancorp',
#  'Canadian national railway co',
#  'Nexen Inc',
#  'CANADIAN PACIFIC RAILWAY',
#  'constellation brands',
#  'Cannell peter b & co',
#  'Canon',
#  'Cantor Fitzgerald',
#  'Cape Securities',
#  'capital conservation',
#  'CAPITAL DIRECTIONS INC',
#  'Capital Investments Inc',
#  'Capital securities investment corp',
#  'American Century Capital Preservation Fund Inc',
#  'capital research & management',
#  'Capital Concepts Investment Corp',
#  'Capital Southwest',
#  'cardiff communications',
#  'Pacific Realm Inc',
#  'carolina power & light',
#  'CARPENTER TECHNOLOGY CORP',
#  'carr friesenhahn & co inc',
#  'CARR SECURITIES Corp',
#  'CARROLL JOHN JOSEPH',
#  'Carrols Corp',
#  'carson benjamin sr',
#  'CARTER SECURITIES CORP',
#  'Carty & Co',
#  'Cascade Corp',
#  'cascade natural gas corp',
#  'Cash Management Trust Of America',
#  'CASIO COMPUTER CO',
#  'CASSETTE EDUCATION SYSTEMS',
#  'Dole Food Co',
#  'castle a m & co',
#  'Castle Convertible Fund',
#  'Caterpillar Inc',
#  'Caterpillar tractor co restricted stock',
#  'Cato',
#  'CAZENOVE',
#  'SYNOVUS FINANCIAL CORP',
#  'cbs broadcasting inc',
#  'cdi',
#  'cedar point',
#  'Cencor Inc',
#  'GENESCO',
#  'Eclickmd Inc',
#  'CENTEX',
#  'Central & South West Corp',
#  'compass bancshares',
#  'COMPASS BANK CORRESPONDENT & INVESTMENT SERVICES DIVISION',
#  'CENTRAL NATURAL RESOURCES',
#  'Central Hudson Gas & Electric Corp',
#  'Central Illinois Light Co',
#  'central illinois public service co',
#  'Cleco power llc',
#  'Central maine power co',
#  'Central ohio coal',
#  'AEP TEXAS CENTRAL CO',
#  'central securities corp',
#  'Central steel & wire co',
#  'CENTRAL VERMONT PUBLIC SERVICE CORP',
#  'century business credit corp',
#  'Vista continental corp',
#  'Century Realty Trust',
#  'CENTURYTEL',
#  'Ceradyne inc',
#  'certron',
#  'lincoln financial distributors inc',
#  'Aim funds group',
#  'Cgs Scientific Corp',
#  'K. w. chambers & co',
#  'Champion home builders co',
#  'champion industries inc',
#  'champion parts inc',
#  'CHAPARRAL RESOURCES INC',
#  'seymour chapnick',
#  'Frank chappelle & co inc',
#  'CHARMING SHOPPES INC',
#  'CHARTER COMMUNICATIONS INC',
#  'Charter Financial',
#  'Magellan health services',
#  'cantel medical corp',
#  'PHOENIX SERIES FUND',
#  'CHASE INVESTMENT COUNSEL CORP',
#  'PHOENIX INVESTMENT COUNSEL INC',
#  'Chattem inc',
#  'SCHRODER CAPITAL FUNDS /DELAWARE',
#  'CHEFFORD MASTER MANUFACTURING CO INC',
#  'CHEM NUT',
#  'Chemed Corp',
#  'chase bank',
#  'Chemical Financial Corp',
#  'Alliancebernstein mid cap growth fund inc',
#  'J P Morgan Chase',
#  'verizon washington dc',
#  'verizon maryland',
#  'Verizon west virginia inc',
#  'Verizon Virginia',
#  'Chesapeake Corp',
#  'Chesapeake Shores Beach & Country Club I',
#  'chesapeake utilities',
#  'Chesebrough ponds inc stock plan',
#  'Chestnut Street Exchange Fund',
#  'Chicago Rivet & Machine',
#  'CHIEF CONSOLIDATED MINING CO',
#  'Chiksan tool co',
#  's.w. childs management',
#  'republic of chile',
#  'kcci ltd',
#  'Chubb',
#  'eurolink securities',
#  'Church Gregory Adams Securities Corp',
#  'CHURCH LOANS & INVESTMENTS TRUST',
#  'CHURCHILL DOWNS INC',
#  'Chyron Corp',
#  'Cincinnati financial corp',
#  'Cincinnati Gas & Electric',
#  'Circle fine art',
#  'cit group',
#  'CITICORP',
#  'Invesco Institutional Na Inc',
#  'Citizens bank',
#  'United magazine co',
#  'associated investment services inc',
#  'citizens communications co',
#  'City securities',
#  'css industries',
#  'AMBASE CORP',
#  'c. j. m. planning',
#  'Clarcor inc',
#  'Clark melvin securities',
#  'premcor refining group',
#  'Clark robert j',
#  'CLARKE',
#  'CLARKSON INDUSTRIES INC',
#  'clary',
#  'cleveland electric illuminating',
#  'clinger & co',
#  'clorox co',
#  'CM SECURITIES INC',
#  'Cmi corp',
#  'CML VARIABLE ANNUITY ACCOUNT A',
#  'Cml variable annuity account b',
#  'CNA FINANCIAL CORP',
#  'prospect street income shares',
#  'CNA INVESTOR SERVICES INC',
#  'COACHMEN INDUSTRIES',
#  'United Vanguard Homes Inc',
#  'Coastal Caribbean Oils & Minerals Ltd',
#  'COASTAL FINANCE',
#  'El Paso Cgp',
#  'VALERO ENERGY',
#  'Coburn & Meredith Inc',
#  'COCA COLA',
#  'COGNITRONICS',
#  'coherent',
#  'COHU INC',
#  'RANGER INDUSTRIES INC',
#  'Coleman co',
#  'Colgate palmolive co',
#  'Collins & co llc',
#  'Collins Industries Inc',
#  'colonial commercial',
#  'LIBERTY FUNDS TRUST I',
#  'Liberty Funds Trust Iii',
#  'Colonial securities inc',
#  'Columbia Daily Income Co',
#  'Columbia energy group',
#  'Columbia Growth Fund Inc',
#  'COLUMBIA MANAGEMENT ADVISORS',
#  'columbus southern power',
#  'COMARCO',
#  'COMBINED INSURANCE CO OF AMERICA',
#  'COMCAST HOLDINGS CORP',
#  'Commerce Bancshares Inc',
#  'Commerce Bankshares Inc',
#  'HANCOCK JOHN INVESTMENT TRUST',
#  'commerce securities corp',
#  'COMMERCIAL INTERNATIONAL CORP',
#  'COMMERCIAL METALS',
#  'Tri valley corp',
#  'COMMONWEALTH EDISON',
#  'Commonwealth industries',
#  'COMMONWEALTH INVESTORS GROUP',
#  'LOWE BROCKENBROUGH & CO',
#  'communications systems inc',
#  'texas new mexico power co',
#  'COMP U CHECK',
#  'CIGNA FUNDS GROUP',
#  'COMPREHENSIVE CARE',
#  'Compudyne',
#  'computer automation inc',
#  'COMPUTER HORIZONS CORP',
#  'group 1 software inc',
#  'ARTESYN TECHNOLOGIES INC',
#  'COMPUTER SCIENCES CORP',
#  'Computer task group',
#  'COMPUTER TRANSCEIVER SYSTEMS',
#  'Comstock resources inc',
#  'Comtech Telecommunications',
#  'Conagra Foods',
#  'CT COMMUNICATIONS INC',
#  'Cone mills',
#  'Congoleum Corp',
#  'FIDELITY CONGRESS STREET FUND',
#  'connecticut general life insurance co',
#  'Connecticut light & power',
#  'Connecticut yankee atomic power co',
#  'Conners & Co Inc',
#  'Conolog',
#  'Consolidation coal co',
#  'Consolidated Edison Co Of New York',
#  'lee sara',
#  'Cnf inc',
#  'consolidated natural gas',
#  'LUMALITE HOLDINGS',
#  'CONSOLIDATED TOMOKA LAND',
#  'continental assurance co',
#  'continental assurance co separate account b',
#  'Continental Casualty Co',
#  'CONTINENTAL CONVEYOR & EQUIPMENT',
#  'Continental',
#  'CONTINENTAL GENERAL INSURANCE CO',
#  'Continental heritage corp',
#  'CONTINENTAL INFORMATION SYSTEMS',
#  'Continental Insurance',
#  'Citizens Inc',
#  'touchstone securities inc',
#  'Continental materials',
#  'Continental real estate partners ltd',
#  'Continental Stock Transfer & Trust',
#  'Bluestone Securities Corp',
#  'fidelity contrafund',
#  'CONTRAN CORP',
#  'Cook inlet region',
#  'Langdon P Cook & Co',
#  'COOKE & BIELER LP',
#  'COOLIDGE LAWRENCE ET AL',
#  'COOPER INDUSTRIES',
#  'Cooper investment co',
#  'Cooper Tire & Rubber Co',
#  'Coors adolph',
#  'COPPER',
#  'COPPS',
#  'corby capital markets',
#  'Cordillera corp',
#  'CORNET STORES',
#  'Corning',
#  'Corning natural gas corp',
#  'corporate bond trust series 5',
#  'corporate fund accumulation program inc',
#  'Corporate investment trust fund first monthly payment serie',
#  'Ing corporate leaders trust',
#  'corporate securities trust intermediate term debt series 1',
#  'cosse international securities',
#  'Truserv',
#  'Cotton states life insurance',
#  'COUGHLIN & Co INC',
#  'Country capital management co',
#  'Countrywide Financial',
#  'COURIER',
#  'cousins properties',
#  'Cox communications',
#  'cpi corp',
#  'Cpt Holdings Inc',
#  'scott & stringfellow inc',
#  'Crane',
#  'CRAWFORD & CO',
#  'crawford stores inc',
#  'Creative investor services inc',
#  'goldsmith milton t',
#  'American general finance corp',
#  'American General Finance',
#  'Crestek',
#  'Crested Corp',
#  'wells fargo bank na',
#  'Croff Enterprises Inc',
#  'cronin & co inc',
#  'Cross a t co',
#  'Crowell Weedon',
#  'CROWN CORK & SEAL CO INC',
#  'CROWN CRAFTS INC',
#  'crystal mountain',
#  'cs capital',
#  'CAPITAL SOUTHWEST VENTURE CORP',
#  'first lexington capital corp',
#  'Cts Corp',
#  'Cuba Republic Of',
#  'cubic',
#  'Cummins inc',
#  'JOHN M. CUNNINGHAM',
#  'CURRAN JOHN P',
#  'Hancock john current interest',
#  'Birds Eye Foods Inc',
#  'Curtiss Wright Corp',
#  'Sensytech',
#  'daiwa securities america',
#  'Dal Piaz Claudio',
#  'Daly john j',
#  'Dana corp',
#  'EIP MICROWAVE INC',
#  'Phoenix Footwear Group Inc',
#  'Dart industries inc',
#  'Dart papesh & co inc',
#  'Darwood Associates Inc',
#  'Smtek International',
#  'DST SYSTEMS',
#  'data systems',
#  'Datamarine International Inc',
#  'Datametrics corp',
#  'dataram',
#  'datascope corp',
#  'Datatab Inc',
#  'daugherty cole inc',
#  'davenport & co llc',
#  'SHARE FINANCIAL SERVICES',
#  'cannarsa david investments',
#  'D.a. Davidson & Co',
#  'davidson harold & associates',
#  'c. r. davis',
#  'SHELBY CULLOM DAVIS & CO LP',
#  'DAWSON JOHN & ASSOCIATES INC',
#  'Daxor Corp',
#  'Target Corp',
#  'Amcast industrial corp',
#  'DAYTON POWER & LIGHT',
#  'DC TRADING & DEVELOPMENT CORP',
#  'Dean holding co',
#  'DELAWARE GROUP EQUITY FUNDS II',
#  'DECORATOR INDUSTRIES',
#  'Deere John Capital Corp',
#  'Del Global Technologies Corp',
#  'Del laboratories inc',
#  'Delaware Group Equity Funds I',
#  'P&h Mining Equipment',
#  'delaware group income funds',
#  'Bankers store inc',
#  'DELMARVA POWER & LIGHT',
#  'Delta air lines',
#  'Delaware Group Equity Funds Iii',
#  'WINDSORTECH',
#  'Deltona',
#  'Deluxe Corp',
#  'dempsey & co',
#  'h. c. denison',
#  'HYDRON TECHNOLOGIES INC',
#  'Dentsply International',
#  'Derand real estate investment trust',
#  'DE ROSE INDUSTRIES',
#  'Gristedes Foods',
#  'Trident rowan group inc',
#  'DETREX',
#  'Detroit Edison',
#  'comerica inc',
#  'Devcon International',
#  'Development corp for israel',
#  'Fidelity oxford street trust',
#  'Dewey Electronics Corp',
#  'Citistreet advisors llc',
#  'Di An Controls Inc',
#  'Lifecore biomedical inc',
#  'Drs technologies inc',
#  'DIAMANT INVESTMENT',
#  'Verizon Delaware',
#  'diapulse corp of america',
#  'HMS SECURITIES INC',
#  'DIEBOLD INC',
#  'bergstrom capital corp',
#  'Veritas dgc',
#  'di giorgio corp',
#  'DIGITAL PRODUCTS CORP',
#  'Dillards inc',
#  'diodes',
#  'dionics',
#  'discovery oil ltd',
#  'disney enterprises inc',
#  'Diversified capital',
#  'INFORETECH WIRELESS TECHNOLOGY INC',
#  'Diversified realty',
#  'Diversified securities',
#  'alliance growth & income fund inc',
#  'WEATHERFORD ENTERRA INC',
#  'tradequest international inc',
#  'Dixie Group Inc',
#  'DR PEPPER CO',
#  'dodge & cox funds',
#  'Doft & Co Inc',
#  'dol resources inc',
#  'dollar directors',
#  'dollar general corp',
#  'RBC DOMINION SECURITIES',
#  'DONALDSON CO INC',
#  'Credit suisse first boston usa inc',
#  'pershing',
#  'Donley Options',
#  'DONNELLEY R R & SONS CO',
#  'Donnkenny',
#  'DONSHIRE PLANNING Corp',
#  'Dorn & Co Inc',
#  'Dorsey & Co',
#  'Constar International',
#  'Double Eagle Petroleum Co',
#  'Douglas & co municipals inc',
#  'dover corp',
#  'dow chemical co',
#  'Dow corning corp',
#  'Dow Jones & Co Inc',
#  'north american gaming & entertainment corp',
#  'Omnicom group',
#  'Interstate Brands',
#  'Dresdner bank ag',
#  'Greate bay casino corp',
#  '1838 BOND DEBENTURE TRADING FUND',
#  'Burnham investors trust',
#  'stratton monthly dividend reit shares inc',
#  'DREXLER TECHNOLOGY CORP',
#  'Dreyfus Fund',
#  'Dreyfus a bonds plus',
#  'DREYFUS PREMIER EQUITY FUNDS INC',
#  'Dreyfus Liquid Assets Inc',
#  'dreyfus money market instruments inc',
#  'Dreyfus growth opportunity fund inc',
#  'dreyfus',
#  'DREYFUS PREMIER THIRD CENTURY FUND INC',
#  'DRIVER HARRIS CO',
#  'Duckwall Alco Stores Inc',
#  'Ducommun Inc',
#  'DUKE ENERGY',
#  'george e. dullnig & co',
#  'R h donnelley corp',
#  'Dupont e i de nemours & co',
#  'Dupree & co inc',
#  'Duquesne light',
#  'Flowserve corp',
#  'dvorak stephen charles',
#  'Triarc Companies',
#  'DY',
#  'dynamics research',
#  'cobra electronics corp',
#  'Dynasil Corp Of America',
#  'Acterna',
#  'Dynetics',
#  'EAGLE EXPLORATION CO',
#  'Eagle food centers inc',
#  'Eagle growth shares',
#  'Eagle Growth Shares Investing Programs',
#  'eagle picher industries',
#  'ealing',
#  'ohana enterprises',
#  'Earth Sciences',
#  'Aquila Distributors',
#  'east tennessee natural gas',
#  'Worksafe Industries Inc',
#  'Wells Fargo Institutional Securities Llc',
#  'EASTERN CO',
#  'Eastern Utilities Investing Corp',
#  'EASTMAN KODAK CO',
#  'Eaton Vance Cash Management Fund',
#  'EATON VANCE SPECIAL INVESTMENT TRUST',
#  'Eaton Corp',
#  'Echelon corp',
#  'Eckerd',
#  'Ecolab inc',
#  'EDGEWOOD MANAGEMENT',
#  'Fam Distributors Inc',
#  'EDISON BROTHERS STORES',
#  'Edo Corp',
#  'Ecc International Corp',
#  'Educational Development Corp',
#  'Twenty services inc',
#  'Horace Mann Life Insurance Co Allegiance Separate Account A',
#  '. g. edwards & sons inc',
#  'Perkinelmer',
#  'Cgu asset management',
#  'locust street securities inc',
#  'eisai co',
#  'El Paso',
#  'el paso electric co',
#  'El paso natural gas co',
#  'elkcorp',
#  'ELDER BEERMAN STORES CORP',
#  'electro catheter corp',
#  'ELECTRO RENT CORP',
#  'Ems Technologies',
#  'ELECTRONIC DATA SYSTEMS',
#  'titan',
#  'Three Five Systems',
#  'Orion diversified technologies',
#  'emcee broadcast products inc',
#  'Elfun trusts',
#  'Elgin National Industries Inc',
#  'R. W. ELLWOOD & CO INC',
#  'elscint',
#  'metwood inc',
#  'ENGEX INC',
#  'EMERSON ELECTRIC CO',
#  'Emerson Radio',
#  'Empire District Electric Co',
#  'Empire securities corp of southern california',
#  'Empire State Building Associates',
#  'ENDOWMENTS',
#  'GLOBAL ONLINE INDIA INC',
#  'quixote',
#  'ENERGY CONVERSION DEVICES INC',
#  'Energy corp of america',
#  'WEATHERFORD INTERNATIONAL INC',
#  'Engel john william',
#  'Engelman securities inc',
#  'Engemann roger & associates',
#  'Ennis Business Forms Inc',
#  'TXU GAS',
#  'Van kampen enterprise fund',
#  'Entwistle co',
#  'VISKASE COMPANIES INC',
#  'Environmental tectonics corp',
#  'channel america broadcasting inc',
#  'AXA ADVISORS LLC',
#  'equifax',
#  'Equitable Resources Inc',
#  'SUNTRUST CAPITAL MARKETS INC',
#  'equitable trust co',
#  'Equity oil co',
#  ...]

# %%
with open('companies_list.txt', 'w') as f:
    f.write('\n'.join(processed_companies)+'\n')
